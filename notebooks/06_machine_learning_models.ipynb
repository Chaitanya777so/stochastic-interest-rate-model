# %%
import pandas as pd
import numpy as np

df = pd.read_csv(
    "../data/processed/fedfunds_features.csv"
)

df.head()
# Out:
#   observation_date  FEDFUNDS  lag_1  lag_2  lag_3  rolling_mean_3  \
# 0       1955-06-01      1.64   1.43   1.43   1.35        1.500000
# 1       1955-07-01      1.68   1.64   1.43   1.43        1.583333
# 2       1955-08-01      1.96   1.68   1.64   1.43        1.760000
# 3       1955-09-01      2.18   1.96   1.68   1.64        1.940000
# 4       1955-10-01      2.24   2.18   1.96   1.68        2.126667
#
#    rolling_mean_12  rate_change  pct_change  volatility_12  trend  year  \
# 0         1.215000         0.21    0.146853       0.270773      1  1955
# 1         1.288333         0.04    0.024390       0.267304      1  1955
# 2         1.350000         0.28    0.166667       0.328468      1  1955
# 3         1.442500         0.22    0.112245       0.392501      1  1955
# 4         1.558333         0.06    0.027523       0.406601      1  1955
#
#    month  quarter
# 0      6        2
# 1      7        3
# 2      8        3
# 3      9        3
# 4     10        4

# %%
y = df["FEDFUNDS"]

# %%
X = df[
[
    "lag_1",
    "lag_2",
    "lag_3",
    "rolling_mean_3",
    "rolling_mean_12",
    "rate_change",
    "volatility_12",
    "year",
    "month",
    "quarter"
]
]

# %%
train_size = int(len(df) * 0.8)

X_train = X[:train_size]
X_test = X[train_size:]

y_train = y[:train_size]
y_test = y[train_size:]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

lr.fit(
    X_train,
    y_train
)
# Out:
# LinearRegression()

# %%
lr_pred = lr.predict(X_test)

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
mae = mean_absolute_error(
    y_test,
    lr_pred
)

rmse = np.sqrt(
    mean_squared_error(
        y_test,
        lr_pred
    )
)

r2 = r2_score(
    y_test,
    lr_pred
)

print("MAE =", mae)
print("RMSE =", rmse)
print("R² =", r2)
# Out:
# MAE = 2.1060557456531525e-15
# RMSE = 2.2218638725179863e-15
# R² = 1.0

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(
    n_estimators=200,
    random_state=42
)

# %%
rf.fit(
    X_train,
    y_train
)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
rf_pred = rf.predict(X_test)

# %%
rf_mae = mean_absolute_error(
    y_test,
    rf_pred
)

rf_rmse = np.sqrt(
    mean_squared_error(
        y_test,
        rf_pred
    )
)

rf_r2 = r2_score(
    y_test,
    rf_pred
)

print("MAE =", rf_mae)
print("RMSE =", rf_rmse)
print("R² =", rf_r2)
# Out:
# MAE = 0.1179859649122814
# RMSE = 0.19977295980146142
# R² = 0.9886057500662754

# %%
results = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Random Forest"
    ],
    "MAE": [
        mae,
        rf_mae
    ],
    "RMSE": [
        rmse,
        rf_rmse
    ],
    "R2": [
        r2,
        rf_r2
    ]
})

results
# Out:
#                Model           MAE          RMSE        R2
# 0  Linear Regression  2.106056e-15  2.221864e-15  1.000000
# 1      Random Forest  1.179860e-01  1.997730e-01  0.988606

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
})

importance = (
    importance
    .sort_values(
        by="Importance",
        ascending=False
    )
)

importance
# Out:
#            Feature  Importance
# 3   rolling_mean_3    0.787460
# 0            lag_1    0.194521
# 5      rate_change    0.007241
# 6    volatility_12    0.005319
# 2            lag_3    0.001369
# 7             year    0.001337
# 4  rolling_mean_12    0.001000
# 1            lag_2    0.000998
# 8            month    0.000551
# 9          quarter    0.000204

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

plt.barh(
    importance["Feature"],
    importance["Importance"]
)

plt.title(
    "Random Forest Feature Importance"
)

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.plot(
    y_test.values,
    label="Actual"
)

plt.plot(
    rf_pred,
    label="Predicted"
)

plt.legend()

plt.title(
    "Actual vs Predicted Rates"
)

plt.show()

# %% [markdown]
# # Machine Learning Findings
#
# 1. Linear Regression established a baseline forecast.
# 2. Random Forest captured non-linear relationships.
# 3. Lagged interest rates were among the strongest predictors.
# 4. Historical rate behavior is highly predictive of future movements.
# 5. Machine learning forecasts were compared with stochastic models.

# %%
print(results)
# Out:
#                Model           MAE          RMSE        R2
# 0  Linear Regression  2.106056e-15  2.221864e-15  1.000000
# 1      Random Forest  1.179860e-01  1.997730e-01  0.988606

# %%
df["target"] = df["FEDFUNDS"].shift(-1)

# %%
df = df.dropna()

# %%
y = df["target"]

# %%
y = df["FEDFUNDS"]
