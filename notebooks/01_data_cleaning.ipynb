# %%
import pandas as pd

df = pd.read_csv("../data/raw/fedfunds.csv")

df.head()
# Out:
#   observation_date  FEDFUNDS
# 0       1954-07-01      0.80
# 1       1954-08-01      1.22
# 2       1954-09-01      1.07
# 3       1954-10-01      0.85
# 4       1954-11-01      0.83

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/fedfunds.csv")

# %%
df.head()
# Out:
#   observation_date  FEDFUNDS
# 0       1954-07-01      0.80
# 1       1954-08-01      1.22
# 2       1954-09-01      1.07
# 3       1954-10-01      0.85
# 4       1954-11-01      0.83

# %%
df.head()
# Out:
#   observation_date  FEDFUNDS
# 0       1954-07-01      0.80
# 1       1954-08-01      1.22
# 2       1954-09-01      1.07
# 3       1954-10-01      0.85
# 4       1954-11-01      0.83

# %%
df.shape
# Out:
# (863, 2)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 863 entries, 0 to 862
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   observation_date  863 non-null    str
#  1   FEDFUNDS          863 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 13.6 KB

# %%
df.describe()
# Out:
#          FEDFUNDS
# count  863.000000
# mean     4.598204
# std      3.533383
# min      0.050000
# 25%      1.920000
# 50%      4.270000
# 75%      6.120000
# max     19.100000

# %%
df.isnull().sum()
# Out:
# observation_date    0
# FEDFUNDS            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.columns)
# Out:
# Index(['observation_date', 'FEDFUNDS'], dtype='str')

# %%
df["observation_date"] = pd.to_datetime(df["observation_date"])

# %%
df.rename(columns={
    "observation_date": "DATE",
    "DGS10": "RATE"
}, inplace=True)

df["DATE"] = pd.to_datetime(df["DATE"])

# %%
print(df.columns)
df.head()
# Out:
# Index(['DATE', 'FEDFUNDS'], dtype='str')
#         DATE  FEDFUNDS
# 0 1954-07-01      0.80
# 1 1954-08-01      1.22
# 2 1954-09-01      1.07
# 3 1954-10-01      0.85
# 4 1954-11-01      0.83

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 863 entries, 0 to 862
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DATE      863 non-null    datetime64[us]
#  1   FEDFUNDS  863 non-null    float64
# dtypes: datetime64[us](1), float64(1)
# memory usage: 13.6 KB

# %%
df.set_index("DATE", inplace=True)

# %%
df.head()
# Out:
#             FEDFUNDS
# DATE
# 1954-07-01      0.80
# 1954-08-01      1.22
# 1954-09-01      1.07
# 1954-10-01      0.85
# 1954-11-01      0.83

# %%
print(df.columns)
# Out:
# Index(['FEDFUNDS'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['FEDFUNDS'], dtype='str')

# %%
df.head(10)
# Out:
#             FEDFUNDS
# DATE
# 1954-07-01      0.80
# 1954-08-01      1.22
# 1954-09-01      1.07
# 1954-10-01      0.85
# 1954-11-01      0.83
# 1954-12-01      1.28
# 1955-01-01      1.39
# 1955-02-01      1.29
# 1955-03-01      1.35
# 1955-04-01      1.43

# %%
df.shape
# Out:
# (863, 1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 863 entries, 1954-07-01 to 2026-05-01
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   FEDFUNDS  863 non-null    float64
# dtypes: float64(1)
# memory usage: 13.5 KB

# %%
df.head(10)
# Out:
#             FEDFUNDS
# DATE
# 1954-07-01      0.80
# 1954-08-01      1.22
# 1954-09-01      1.07
# 1954-10-01      0.85
# 1954-11-01      0.83
# 1954-12-01      1.28
# 1955-01-01      1.39
# 1955-02-01      1.29
# 1955-03-01      1.35
# 1955-04-01      1.43

# %%
df.index
# Out:
# DatetimeIndex(['1954-07-01', '1954-08-01', '1954-09-01', '1954-10-01',
#                '1954-11-01', '1954-12-01', '1955-01-01', '1955-02-01',
#                '1955-03-01', '1955-04-01',
#                ...
#                '2025-08-01', '2025-09-01', '2025-10-01', '2025-11-01',
#                '2025-12-01', '2026-01-01', '2026-02-01', '2026-03-01',
#                '2026-04-01', '2026-05-01'],
#               dtype='datetime64[us]', name='DATE', length=863, freq=None)

# %%
df = df.reset_index()

print(df.columns)
df.head()
# Out:
# Index(['DATE', 'FEDFUNDS'], dtype='str')
#         DATE  FEDFUNDS
# 0 1954-07-01      0.80
# 1 1954-08-01      1.22
# 2 1954-09-01      1.07
# 3 1954-10-01      0.85
# 4 1954-11-01      0.83

# %%
df = df.reset_index()

df["DATE"] = pd.to_datetime(df["DATE"])

df.head()
# Out:
#    index       DATE  FEDFUNDS
# 0      0 1954-07-01      0.80
# 1      1 1954-08-01      1.22
# 2      2 1954-09-01      1.07
# 3      3 1954-10-01      0.85
# 4      4 1954-11-01      0.83

# %%
df = df.drop(columns=["index"])

df.head()
# Out:
#         DATE  FEDFUNDS
# 0 1954-07-01      0.80
# 1 1954-08-01      1.22
# 2 1954-09-01      1.07
# 3 1954-10-01      0.85
# 4 1954-11-01      0.83

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 863 entries, 0 to 862
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DATE      863 non-null    datetime64[us]
#  1   FEDFUNDS  863 non-null    float64
# dtypes: datetime64[us](1), float64(1)
# memory usage: 13.6 KB

# %%
df.isnull().sum()
# Out:
# DATE        0
# FEDFUNDS    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                              DATE    FEDFUNDS
# count                         863  863.000000
# mean   1990-06-01 08:45:36.500579    4.598204
# min           1954-07-01 00:00:00    0.050000
# 25%           1972-06-16 00:00:00    1.920000
# 50%           1990-06-01 00:00:00    4.270000
# 75%           2008-05-16 12:00:00    6.120000
# max           2026-05-01 00:00:00   19.100000
# std                           NaN    3.533383
